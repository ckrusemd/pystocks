# %% [markdown]
# # (PEP): PepsiCo Inc. Common Stock

# %%
    from functions import *
    collect_tune_and_predict('PEP',n_ahead = 365)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fe714d78400>
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# {'changepoint_prior_scale': 1, 'seasonality_prior_scale': 1.0, 'rmse': 5.563463888726961}
# {'fig1': <Figure size 720x432 with 1 Axes>,
#  'fig2': <Figure size 648x648 with 3 Axes>,
#  'fig3': <Figure size 720x432 with 1 Axes>}
