# %% [markdown]
# # (CSAN): Cosan S.A. ADS

# %%
    from functions import *
    collect_tune_and_predict('CSAN',n_ahead = 365)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fb58cd66190>
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# {'changepoint_prior_scale': 1, 'seasonality_prior_scale': 1.0, 'rmse': 2.1416977037820906}
# {'fig1': <Figure size 720x432 with 1 Axes>,
#  'fig2': <Figure size 648x432 with 2 Axes>,
#  'fig3': <Figure size 720x432 with 1 Axes>}
