# %% [markdown]
# # (RTX): Raytheon Technologies Corporation Common Stock

# %%
    from functions import *
    collect_tune_and_predict('RTX',n_ahead = 365)
# Out:
# [*********************100%***********************]  1 of 1 completed
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f64b9916610>
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# {'changepoint_prior_scale': 1, 'seasonality_prior_scale': 1.0, 'rmse': 6.947605743653295}
# {'fig1': <Figure size 720x432 with 1 Axes>,
#  'fig2': <Figure size 648x648 with 3 Axes>,
#  'fig3': <Figure size 720x432 with 1 Axes>}
